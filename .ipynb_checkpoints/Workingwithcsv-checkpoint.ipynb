# %%
# !pip install requests

# %%
import pandas as pd

# %% [markdown]
# # Opening csv locally

# %%
df = pd.read_csv("aug_train.csv")
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# # Opening from a url

# %%
import requests
from io import StringIO

url = "https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url,headers = headers)
data = StringIO(req.text)

df = pd.read_csv(data)
# df
# df.columns
# df.shape
# Out:
# (200, 3)

# %% [markdown]
# # Sep param

# %%
pd.read_csv('abc.tsv',sep="\t",name=["","","",""])

# %% [markdown]
# # Index col params

# %%
pd.read_csv("abc.csv",index_col='exisiting_col_name')

# %% [markdown]
# # Header

# %%
pd.read_csv("abc.csv",headers=1)

# %% [markdown]
# # useCols

# %%
pd.read_csv("aug_train.csv",usecols=['city_development_index','gender','education_level'])
# Out:
#        city_development_index gender education_level
# 0                       0.920   Male        Graduate
# 1                       0.776   Male        Graduate
# 2                       0.624    NaN        Graduate
# 3                       0.789    NaN        Graduate
# 4                       0.767   Male         Masters
# ...                       ...    ...             ...
# 19153                   0.878   Male        Graduate
# 19154                   0.920   Male        Graduate
# 19155                   0.920   Male        Graduate
# 19156                   0.802   Male     High School
# 19157                   0.855    NaN  Primary School
#
# [19158 rows x 3 columns]

# %%
df = pd.read_csv("aug_train.csv", usecols=['city_development_index'])
series = df['city_development_index']
series
# Out:
# 0        0.920
# 1        0.776
# 2        0.624
# 3        0.789
# 4        0.767
#          ...
# 19153    0.878
# 19154    0.920
# 19155    0.920
# 19156    0.802
# 19157    0.855
# Name: city_development_index, Length: 19158, dtype: float64

# %%
#rows
# df = pd.read_csv("aug_train.csv",skiprows=[0,1])
df = pd.read_csv("aug_train.csv",nrows=100)
df
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# #  Encoding

# %%
pd.read_csv("zomato.csv",encoding='latin-1')

# %% [markdown]
# # Skip bad lines

# %%
pd.read_csv("zomato.csv",encoding='latin-1',error_bad_line=False)

# %% [markdown]
# # d_types

# %%
pd.read_csv("zomato.csv",dtype={'target':int})

# %% [markdown]
# # Handeling dates

# %%
pd.read_csv("zomato.csv",parse_dates=['dates']).info()

# %% [markdown]
# # Convertors

# %%
def rename(name):
    if name == 'Male':
        return "M"
    else:
        return "F"
    return name

# %%
pd.read_csv("aug_train.csv",converters={"gender":rename})
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920      M
# 1            29725   city_40                   0.776      M
# 2            11561   city_21                   0.624      F
# 3            33241  city_115                   0.789      F
# 4              666  city_162                   0.767      M
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878      M
# 19154        31398  city_103                   0.920      M
# 19155        24576  city_103                   0.920      M
# 19156         5756   city_65                   0.802      M
# 19157        23834   city_67                   0.855      F
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df = pd.read_csv("aug_train.csv", converters={"gender": rename}, na_values=['M'])
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920      M
# 1            29725   city_40                   0.776      M
# 2            11561   city_21                   0.624      F
# 3            33241  city_115                   0.789      F
# 4              666  city_162                   0.767      M
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878      M
# 19154        31398  city_103                   0.920      M
# 19155        24576  city_103                   0.920      M
# 19156         5756   city_65                   0.802      M
# 19157        23834   city_67                   0.855      F
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Loading huge ds into chunks

# %%
df = pd.read_csv("aug_train.csv", chunksize=5000)

# %%
for chunk in df:
    print(chunk.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
