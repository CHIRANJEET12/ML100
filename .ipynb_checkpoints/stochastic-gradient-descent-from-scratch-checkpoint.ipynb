# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import time

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X.shape, y.shape
# Out:
# ((442, 10), (442,))

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
X_train.shape[0],X_train.shape[1]
# Out:
# (353, 10)

# %%
class SGDRegressor:
    def __init__(self,lnr,epochs):
        self.coef_ = None
        self.intercept_ = None
        self.lnr = lnr
        self.epochs = epochs

    def fit(self,X_train,y_train):
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])

        for i in range(self.epochs):
            for j in range(X_train.shape[0]):
                idx = np.random.randint(0,X_train.shape[0])

                y_hat = np.dot(X_train[idx],self.coef_) + self.intercept_

                intercept_der = -2 * (y_train[idx]-y_hat)
                self.intercept_ = self.intercept_ - (self.lnr * intercept_der)

                coef_der = -2 * np.dot((y_train[idx] - y_hat),X_train[idx])
                self.coef_ = self.coef_ - (self.lnr * coef_der)

        print(self.intercept_,self.coef_)  

    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
sgd = SGDRegressor(lnr=0.01,epochs=40)

# %%
start = time.time()
sgd.fit(X_train,y_train)
print("The time taken is",time.time() - start)
# Out:
# 149.88704855677017 [  69.72090659  -41.11762235  300.79709599  229.46120119   29.58168128
#    -9.43008166 -159.05957149  124.84028597  283.46899893  119.0062019 ]
# The time taken is 0.522057294845581

# %%
y_pred = sgd.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.413864036033154

# %%
from sklearn.linear_model import SGDRegressor

# %%
lr = SGDRegressor(max_iter=100,learning_rate='constant',eta0=0.02)

# %%
lr.fit(X_train,y_train)
# Out:
# SGDRegressor(eta0=0.02, learning_rate='constant', max_iter=100)

# %%
y_pred = lr.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4420797890829208
